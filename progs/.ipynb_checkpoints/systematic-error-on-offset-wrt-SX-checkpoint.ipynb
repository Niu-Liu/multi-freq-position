# %% [markdown]
# This notebook shows effects of large-scale error on the multi-band position offsets wrt. SX-band position.

# %%
from astropy.table import Table, join, Column
from astropy import units as u
import astropy.coordinates as coord
from astropy.coordinates import SkyCoord
import numpy as np

import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator
# %matplotlib inline

# %%
comsou = Table.read("../data/common-source-position.fits")

# %% [markdown]
# # 1. On the R.A. and decl.

# %%
# Histogram of dra and ddec
fig, ((ax0, ax1),
      (ax2, ax3), (ax4, ax5),
      (ax6, ax7), (ax8, ax9),
      (ax10, ax11), (ax12, ax13),
      (ax14, ax15), (ax16, ax17)) = plt.subplots(
    figsize=(8, 18), ncols=2, nrows=9, sharex=True, sharey=True)

# n_bins = 25
bins_set = np.linspace(-2, 2, 50)

# Weights to calculate the per cent
wgt = 100 / len(comsou) * np.ones_like(comsou["ra"])

# Plot
# R.A. difference
# K - S/X
ax0.hist(comsou["dra_k"], bins_set, histtype="step", fill=False, weights=wgt)

# K - S/X (adjusted by vsh01, all sources)
ax2.hist(comsou["dra_k_all1"], bins_set, histtype="step", fill=False, weights=wgt)

# K - S/X (adjusted by vsh02, all sources)
ax4.hist(comsou["dra_k_all2"], bins_set, histtype="step", fill=False, weights=wgt)

# K - S/X (adjusted by vsh01, clean sources)
ax6.hist(comsou["dra_k_cln1"], bins_set, histtype="step", fill=False, weights=wgt)

# K - S/X (adjusted by vsh02, clean sources)
ax8.hist(comsou["dra_k_cln2"], bins_set, histtype="step", fill=False, weights=wgt)

# K - S/X (adjusted by vsh01, common sources)
ax10.hist(comsou["dra_k_com1"], bins_set, histtype="step", fill=False, weights=wgt)

# K - S/X (adjusted by vsh02, common sources)
ax12.hist(comsou["dra_k_com2"], bins_set, histtype="step", fill=False, weights=wgt)

# K - S/X (adjusted by vsh01, common clean sources)
ax14.hist(comsou["dra_k_ccl1"], bins_set, histtype="step", fill=False, weights=wgt)

# K - S/X (adjusted by vsh02, common clean sources)
ax16.hist(comsou["dra_k_ccl2"], bins_set, histtype="step", fill=False, weights=wgt)

# Decl. difference
# K - S/X
ax1.hist(comsou["ddec_k"], bins_set, histtype="step", fill=False, weights=wgt)

# K - S/X (adjusted by vsh01, all sources)
ax3.hist(comsou["ddec_k_all1"], bins_set, histtype="step", fill=False, weights=wgt)

# K - S/X (adjusted by vsh02, all sources)
ax5.hist(comsou["ddec_k_all2"], bins_set, histtype="step", fill=False, weights=wgt)

# K - S/X (adjusted by vsh01, clean sources)
ax7.hist(comsou["ddec_k_cln1"], bins_set, histtype="step", fill=False, weights=wgt)

# K - S/X (adjusted by vsh02, clean sources)
ax9.hist(comsou["ddec_k_cln2"], bins_set, histtype="step", fill=False, weights=wgt)

# K - S/X (adjusted by vsh01, common sources)
ax11.hist(comsou["ddec_k_com1"], bins_set, histtype="step", fill=False, weights=wgt)

# K - S/X (adjusted by vsh02, common sources)
ax13.hist(comsou["ddec_k_com2"], bins_set, histtype="step", fill=False, weights=wgt)

# K - S/X (adjusted by vsh01, clean sources)
ax15.hist(comsou["ddec_k_ccl1"], bins_set, histtype="step", fill=False, weights=wgt)

# K - S/X (adjusted by vsh02, clean sources)
ax17.hist(comsou["ddec_k_ccl2"], bins_set, histtype="step", fill=False, weights=wgt)

# Vetical lines
ax0.vlines(0, 0, 35, "r", lw=0.5)
ax1.vlines(0, 0, 35, "r", lw=0.5)
ax2.vlines(0, 0, 35, "r", lw=0.5)
ax3.vlines(0, 0, 35, "r", lw=0.5)
ax4.vlines(0, 0, 35, "r", lw=0.5)
ax5.vlines(0, 0, 35, "r", lw=0.5)
ax6.vlines(0, 0, 35, "r", lw=0.5)
ax7.vlines(0, 0, 35, "r", lw=0.5)
ax8.vlines(0, 0, 35, "r", lw=0.5)
ax9.vlines(0, 0, 35, "r", lw=0.5)
ax10.vlines(0, 0, 35, "r", lw=0.5)
ax11.vlines(0, 0, 35, "r", lw=0.5)
ax12.vlines(0, 0, 35, "r", lw=0.5)
ax13.vlines(0, 0, 35, "r", lw=0.5)
ax14.vlines(0, 0, 35, "r", lw=0.5)
ax15.vlines(0, 0, 35, "r", lw=0.5)
ax16.vlines(0, 0, 35, "r", lw=0.5)
ax17.vlines(0, 0, 35, "r", lw=0.5)

# Double ticks
ax0.xaxis.set_ticks_position("both")
ax0.yaxis.set_ticks_position("both")
ax1.xaxis.set_ticks_position("both")
ax1.yaxis.set_ticks_position("both")
ax2.xaxis.set_ticks_position("both")
ax2.yaxis.set_ticks_position("both")
ax3.xaxis.set_ticks_position("both")
ax3.yaxis.set_ticks_position("both")
ax4.xaxis.set_ticks_position("both")
ax4.yaxis.set_ticks_position("both")
ax5.xaxis.set_ticks_position("both")
ax5.yaxis.set_ticks_position("both")
ax6.xaxis.set_ticks_position("both")
ax6.yaxis.set_ticks_position("both")
ax7.xaxis.set_ticks_position("both")
ax7.yaxis.set_ticks_position("both")
ax8.xaxis.set_ticks_position("both")
ax8.yaxis.set_ticks_position("both")
ax9.xaxis.set_ticks_position("both")
ax9.yaxis.set_ticks_position("both")
ax10.xaxis.set_ticks_position("both")
ax10.yaxis.set_ticks_position("both")
ax11.xaxis.set_ticks_position("both")
ax11.yaxis.set_ticks_position("both")
ax12.xaxis.set_ticks_position("both")
ax12.yaxis.set_ticks_position("both")
ax13.xaxis.set_ticks_position("both")
ax13.yaxis.set_ticks_position("both")
ax14.xaxis.set_ticks_position("both")
ax14.yaxis.set_ticks_position("both")
ax15.xaxis.set_ticks_position("both")
ax15.yaxis.set_ticks_position("both")
ax16.xaxis.set_ticks_position("both")
ax16.yaxis.set_ticks_position("both")
ax17.xaxis.set_ticks_position("both")
ax17.yaxis.set_ticks_position("both")

ax0.set_ylabel("% (Original)", fontsize=12)
ax2.set_ylabel("% (all-01)", fontsize=12)
ax4.set_ylabel("% (all-02)", fontsize=12)
ax6.set_ylabel("% (clean-01)", fontsize=12)
ax8.set_ylabel("% (clean-02)", fontsize=12)
ax10.set_ylabel("% (common-01)", fontsize=12)
ax12.set_ylabel("% (common-02)", fontsize=12)
ax14.set_ylabel("% (comcln-01)", fontsize=12)
ax16.set_ylabel("% (comcln-02)", fontsize=12)

ax16.set_xlabel("$\Delta\\alpha\cos\delta$ (K$-$X, mas)", fontsize=12)
ax16.xaxis.set_minor_locator(MultipleLocator(0.2))

ax17.xaxis.set_minor_locator(MultipleLocator(0.25))
ax17.set_xlabel("$\Delta\delta$ (K$-$X, mas)", fontsize=12)

ax0.set_ylim([0, 35])
plt.tight_layout()

# %%
# Histogram of dra and ddec
fig, ((ax0, ax1),
      (ax2, ax3), (ax4, ax5),
      (ax6, ax7), (ax8, ax9),
      (ax10, ax11), (ax12, ax13),
      (ax14, ax15), (ax16, ax17)) = plt.subplots(
    figsize=(8, 18), ncols=2, nrows=9, sharex=True, sharey=True)

# n_bins = 25
bins_set = np.linspace(-2, 2, 50)

# Weights to calculate the per cent
wgt = 100 / len(comsou) * np.ones_like(comsou["ra"])

# Plot
# R.A. difference
# Ka - S/X
ax0.hist(comsou["dra_ka"], bins_set, histtype="step", fill=False, weights=wgt)

# Ka - S/X (adjusted by vsh01, all sources)
ax2.hist(comsou["dra_ka_all1"], bins_set, histtype="step", fill=False, weights=wgt)

# Ka - S/X (adjusted by vsh02, all sources)
ax4.hist(comsou["dra_ka_all2"], bins_set, histtype="step", fill=False, weights=wgt)

# Ka - S/X (adjusted by vsh01, clean sources)
ax6.hist(comsou["dra_ka_cln1"], bins_set, histtype="step", fill=False, weights=wgt)

# Ka - S/X (adjusted by vsh02, clean sources)
ax8.hist(comsou["dra_ka_cln2"], bins_set, histtype="step", fill=False, weights=wgt)

# Ka - S/X (adjusted by vsh01, common sources)
ax10.hist(comsou["dra_ka_com1"], bins_set, histtype="step", fill=False, weights=wgt)

# Ka - S/X (adjusted by vsh02, common sources)
ax12.hist(comsou["dra_ka_com2"], bins_set, histtype="step", fill=False, weights=wgt)

# Ka - S/X (adjusted by vsh01, common clean sources)
ax14.hist(comsou["dra_ka_ccl1"], bins_set, histtype="step", fill=False, weights=wgt)

# Ka - S/X (adjusted by vsh02, common clean sources)
ax16.hist(comsou["dra_ka_ccl2"], bins_set, histtype="step", fill=False, weights=wgt)

# Decl. difference
# Ka - S/X
ax1.hist(comsou["ddec_ka"], bins_set, histtype="step", fill=False, weights=wgt)

# Ka - S/X (adjusted by vsh01, all sources)
ax3.hist(comsou["ddec_ka_all1"], bins_set, histtype="step", fill=False, weights=wgt)

# Ka - S/X (adjusted by vsh02, all sources)
ax5.hist(comsou["ddec_ka_all2"], bins_set, histtype="step", fill=False, weights=wgt)

# Ka - S/X (adjusted by vsh01, clean sources)
ax7.hist(comsou["ddec_ka_cln1"], bins_set, histtype="step", fill=False, weights=wgt)

# Ka - S/X (adjusted by vsh02, clean sources)
ax9.hist(comsou["ddec_ka_cln2"], bins_set, histtype="step", fill=False, weights=wgt)

# Ka - S/X (adjusted by vsh01, common sources)
ax11.hist(comsou["ddec_ka_com1"], bins_set, histtype="step", fill=False, weights=wgt)

# Ka - S/X (adjusted by vsh02, common sources)
ax13.hist(comsou["ddec_ka_com2"], bins_set, histtype="step", fill=False, weights=wgt)

# Ka - S/X (adjusted by vsh01, clean sources)
ax15.hist(comsou["ddec_ka_ccl1"], bins_set, histtype="step", fill=False, weights=wgt)

# Ka - S/X (adjusted by vsh02, clean sources)
ax17.hist(comsou["ddec_ka_ccl2"], bins_set, histtype="step", fill=False, weights=wgt)

# Vetical lines
ax0.vlines(0, 0, 35, "r", lw=0.5)
ax1.vlines(0, 0, 35, "r", lw=0.5)
ax2.vlines(0, 0, 35, "r", lw=0.5)
ax3.vlines(0, 0, 35, "r", lw=0.5)
ax4.vlines(0, 0, 35, "r", lw=0.5)
ax5.vlines(0, 0, 35, "r", lw=0.5)
ax6.vlines(0, 0, 35, "r", lw=0.5)
ax7.vlines(0, 0, 35, "r", lw=0.5)
ax8.vlines(0, 0, 35, "r", lw=0.5)
ax9.vlines(0, 0, 35, "r", lw=0.5)
ax10.vlines(0, 0, 35, "r", lw=0.5)
ax11.vlines(0, 0, 35, "r", lw=0.5)
ax12.vlines(0, 0, 35, "r", lw=0.5)
ax13.vlines(0, 0, 35, "r", lw=0.5)
ax14.vlines(0, 0, 35, "r", lw=0.5)
ax15.vlines(0, 0, 35, "r", lw=0.5)
ax16.vlines(0, 0, 35, "r", lw=0.5)
ax17.vlines(0, 0, 35, "r", lw=0.5)

# Double ticks
ax0.xaxis.set_ticks_position("both")
ax0.yaxis.set_ticks_position("both")
ax1.xaxis.set_ticks_position("both")
ax1.yaxis.set_ticks_position("both")
ax2.xaxis.set_ticks_position("both")
ax2.yaxis.set_ticks_position("both")
ax3.xaxis.set_ticks_position("both")
ax3.yaxis.set_ticks_position("both")
ax4.xaxis.set_ticks_position("both")
ax4.yaxis.set_ticks_position("both")
ax5.xaxis.set_ticks_position("both")
ax5.yaxis.set_ticks_position("both")
ax6.xaxis.set_ticks_position("both")
ax6.yaxis.set_ticks_position("both")
ax7.xaxis.set_ticks_position("both")
ax7.yaxis.set_ticks_position("both")
ax8.xaxis.set_ticks_position("both")
ax8.yaxis.set_ticks_position("both")
ax9.xaxis.set_ticks_position("both")
ax9.yaxis.set_ticks_position("both")
ax10.xaxis.set_ticks_position("both")
ax10.yaxis.set_ticks_position("both")
ax11.xaxis.set_ticks_position("both")
ax11.yaxis.set_ticks_position("both")
ax12.xaxis.set_ticks_position("both")
ax12.yaxis.set_ticks_position("both")
ax13.xaxis.set_ticks_position("both")
ax13.yaxis.set_ticks_position("both")
ax14.xaxis.set_ticks_position("both")
ax14.yaxis.set_ticks_position("both")
ax15.xaxis.set_ticks_position("both")
ax15.yaxis.set_ticks_position("both")
ax16.xaxis.set_ticks_position("both")
ax16.yaxis.set_ticks_position("both")
ax17.xaxis.set_ticks_position("both")
ax17.yaxis.set_ticks_position("both")

ax0.set_ylabel("% (Original)", fontsize=12)
ax2.set_ylabel("% (all-01)", fontsize=12)
ax4.set_ylabel("% (all-02)", fontsize=12)
ax6.set_ylabel("% (clean-01)", fontsize=12)
ax8.set_ylabel("% (clean-02)", fontsize=12)
ax10.set_ylabel("% (common-01)", fontsize=12)
ax12.set_ylabel("% (common-02)", fontsize=12)
ax14.set_ylabel("% (comcln-01)", fontsize=12)
ax16.set_ylabel("% (comcln-02)", fontsize=12)

ax16.set_xlabel("$\Delta\\alpha\cos\delta$ (Ka$-$X, mas)", fontsize=12)
ax16.xaxis.set_minor_locator(MultipleLocator(0.2))

ax17.xaxis.set_minor_locator(MultipleLocator(0.25))
ax17.set_xlabel("$\Delta\delta$ (Ka$-$X, mas)", fontsize=12)

ax0.set_ylim([0, 35])
plt.tight_layout()

# %%
# Histogram of dra and ddec
fig, ((ax0, ax1),
      (ax2, ax3), (ax4, ax5),
      (ax6, ax7), (ax8, ax9),
      (ax10, ax11), (ax12, ax13),
      (ax14, ax15), (ax16, ax17)) = plt.subplots(
    figsize=(8, 18), ncols=2, nrows=9, sharex=True, sharey=True)

# n_bins = 25
bins_set = np.linspace(-2, 2, 50)

# Weights to calculate the per cent
wgt = 100 / len(comsou) * np.ones_like(comsou["ra"])

# Plot
# R.A. difference
# Gaia - S/X
ax0.hist(comsou["dra_g"], bins_set, histtype="step", fill=False, weights=wgt)

# Gaia - S/X (adjusted by vsh01, all sources)
ax2.hist(comsou["dra_g_all1"], bins_set, histtype="step", fill=False, weights=wgt)

# Gaia - S/X (adjusted by vsh02, all sources)
ax4.hist(comsou["dra_g_all2"], bins_set, histtype="step", fill=False, weights=wgt)

# Gaia - S/X (adjusted by vsh01, clean sources)
ax6.hist(comsou["dra_g_cln1"], bins_set, histtype="step", fill=False, weights=wgt)

# Gaia - S/X (adjusted by vsh02, clean sources)
ax8.hist(comsou["dra_g_cln2"], bins_set, histtype="step", fill=False, weights=wgt)

# Gaia - S/X (adjusted by vsh01, common sources)
ax10.hist(comsou["dra_g_com1"], bins_set, histtype="step", fill=False, weights=wgt)

# Gaia - S/X (adjusted by vsh02, common sources)
ax12.hist(comsou["dra_g_com2"], bins_set, histtype="step", fill=False, weights=wgt)

# Gaia - S/X (adjusted by vsh01, common clean sources)
ax14.hist(comsou["dra_g_ccl1"], bins_set, histtype="step", fill=False, weights=wgt)

# Gaia - S/X (adjusted by vsh02, common clean sources)
ax16.hist(comsou["dra_g_ccl2"], bins_set, histtype="step", fill=False, weights=wgt)

# Decl. difference
# Gaia - S/X
ax1.hist(comsou["ddec_g"], bins_set, histtype="step", fill=False, weights=wgt)

# Gaia - S/X (adjusted by vsh01, all sources)
ax3.hist(comsou["ddec_g_all1"], bins_set, histtype="step", fill=False, weights=wgt)

# Gaia - S/X (adjusted by vsh02, all sources)
ax5.hist(comsou["ddec_g_all2"], bins_set, histtype="step", fill=False, weights=wgt)

# Gaia - S/X (adjusted by vsh01, clean sources)
ax7.hist(comsou["ddec_g_cln1"], bins_set, histtype="step", fill=False, weights=wgt)

# Gaia - S/X (adjusted by vsh02, clean sources)
ax9.hist(comsou["ddec_g_cln2"], bins_set, histtype="step", fill=False, weights=wgt)

# Gaia - S/X (adjusted by vsh01, common sources)
ax11.hist(comsou["ddec_g_com1"], bins_set, histtype="step", fill=False, weights=wgt)

# Gaia - S/X (adjusted by vsh02, common sources)
ax13.hist(comsou["ddec_g_com2"], bins_set, histtype="step", fill=False, weights=wgt)

# Gaia - S/X (adjusted by vsh01, clean sources)
ax15.hist(comsou["ddec_g_ccl1"], bins_set, histtype="step", fill=False, weights=wgt)

# Gaia - S/X (adjusted by vsh02, clean sources)
ax17.hist(comsou["ddec_g_ccl2"], bins_set, histtype="step", fill=False, weights=wgt)

# Vetical lines
ymin, ymax = 0, 15
ax0.vlines(0, ymin, ymax, "r", lw=0.5)
ax1.vlines(0, ymin, ymax, "r", lw=0.5)
ax2.vlines(0, ymin, ymax, "r", lw=0.5)
ax3.vlines(0, ymin, ymax, "r", lw=0.5)
ax4.vlines(0, ymin, ymax, "r", lw=0.5)
ax5.vlines(0, ymin, ymax, "r", lw=0.5)
ax6.vlines(0, ymin, ymax, "r", lw=0.5)
ax7.vlines(0, ymin, ymax, "r", lw=0.5)
ax8.vlines(0, ymin, ymax, "r", lw=0.5)
ax9.vlines(0, ymin, ymax, "r", lw=0.5)
ax10.vlines(0, ymin, ymax, "r", lw=0.5)
ax11.vlines(0, ymin, ymax, "r", lw=0.5)
ax12.vlines(0, ymin, ymax, "r", lw=0.5)
ax13.vlines(0, ymin, ymax, "r", lw=0.5)
ax14.vlines(0, ymin, ymax, "r", lw=0.5)
ax15.vlines(0, ymin, ymax, "r", lw=0.5)
ax16.vlines(0, ymin, ymax, "r", lw=0.5)
ax17.vlines(0, ymin, ymax, "r", lw=0.5)
ax0.set_ylim([ymin, ymax])

# Double ticks
ax0.xaxis.set_ticks_position("both")
ax0.yaxis.set_ticks_position("both")
ax1.xaxis.set_ticks_position("both")
ax1.yaxis.set_ticks_position("both")
ax2.xaxis.set_ticks_position("both")
ax2.yaxis.set_ticks_position("both")
ax3.xaxis.set_ticks_position("both")
ax3.yaxis.set_ticks_position("both")
ax4.xaxis.set_ticks_position("both")
ax4.yaxis.set_ticks_position("both")
ax5.xaxis.set_ticks_position("both")
ax5.yaxis.set_ticks_position("both")
ax6.xaxis.set_ticks_position("both")
ax6.yaxis.set_ticks_position("both")
ax7.xaxis.set_ticks_position("both")
ax7.yaxis.set_ticks_position("both")
ax8.xaxis.set_ticks_position("both")
ax8.yaxis.set_ticks_position("both")
ax9.xaxis.set_ticks_position("both")
ax9.yaxis.set_ticks_position("both")
ax10.xaxis.set_ticks_position("both")
ax10.yaxis.set_ticks_position("both")
ax11.xaxis.set_ticks_position("both")
ax11.yaxis.set_ticks_position("both")
ax12.xaxis.set_ticks_position("both")
ax12.yaxis.set_ticks_position("both")
ax13.xaxis.set_ticks_position("both")
ax13.yaxis.set_ticks_position("both")
ax14.xaxis.set_ticks_position("both")
ax14.yaxis.set_ticks_position("both")
ax15.xaxis.set_ticks_position("both")
ax15.yaxis.set_ticks_position("both")
ax16.xaxis.set_ticks_position("both")
ax16.yaxis.set_ticks_position("both")
ax17.xaxis.set_ticks_position("both")
ax17.yaxis.set_ticks_position("both")

ax0.set_ylabel("% (Original)", fontsize=12)
ax2.set_ylabel("% (all-01)", fontsize=12)
ax4.set_ylabel("% (all-02)", fontsize=12)
ax6.set_ylabel("% (clean-01)", fontsize=12)
ax8.set_ylabel("% (clean-02)", fontsize=12)
ax10.set_ylabel("% (common-01)", fontsize=12)
ax12.set_ylabel("% (common-02)", fontsize=12)
ax14.set_ylabel("% (comcln-01)", fontsize=12)
ax16.set_ylabel("% (comcln-02)", fontsize=12)

ax16.set_xlabel("$\Delta\\alpha\cos\delta$ (Gaia$-$X, mas)", fontsize=12)
ax16.xaxis.set_minor_locator(MultipleLocator(0.2))

ax17.xaxis.set_minor_locator(MultipleLocator(0.25))
ax17.set_xlabel("$\Delta\delta$ (Gaia$-$X, mas)", fontsize=12)

plt.tight_layout()

# %% [markdown]
# In general, the adjustment of 16-parameters from all sources seems to remove the bias in $\Delta\alpha^*$ and $\delta$.

# %% [markdown]
# # 2. On the angular separation

# %%
# Offset of K-X (original vs. adjusted by vsh01 vs. adjusted by vsh02)
fig, (ax0, ax1, ax2, ax3, ax4, ax5, ax6, ax7) = plt.subplots(
    figsize=(4, 24), nrows=8, sharex=True, sharey=True)

ax0.plot(comsou["ang_sep_k"], comsou["ang_sep_k_all1"], ".", ms=2)
ax1.plot(comsou["ang_sep_k"], comsou["ang_sep_k_all2"], ".", ms=2)
ax2.plot(comsou["ang_sep_k"], comsou["ang_sep_k_cln1"], ".", ms=2)
ax3.plot(comsou["ang_sep_k"], comsou["ang_sep_k_cln2"], ".", ms=2)
ax4.plot(comsou["ang_sep_k"], comsou["ang_sep_k_com1"], ".", ms=2)
ax5.plot(comsou["ang_sep_k"], comsou["ang_sep_k_com2"], ".", ms=2)
ax6.plot(comsou["ang_sep_k"], comsou["ang_sep_k_cln1"], ".", ms=2)
ax7.plot(comsou["ang_sep_k"], comsou["ang_sep_k_cln2"], ".", ms=2)

ax0.set_xscale("log")
ax0.set_yscale("log")

ax0.xaxis.set_ticks_position("both")
ax0.yaxis.set_ticks_position("both")
ax1.xaxis.set_ticks_position("both")
ax1.yaxis.set_ticks_position("both")
ax2.xaxis.set_ticks_position("both")
ax2.yaxis.set_ticks_position("both")
ax3.xaxis.set_ticks_position("both")
ax3.yaxis.set_ticks_position("both")
ax4.xaxis.set_ticks_position("both")
ax4.yaxis.set_ticks_position("both")
ax5.xaxis.set_ticks_position("both")
ax5.yaxis.set_ticks_position("both")
ax6.xaxis.set_ticks_position("both")
ax6.yaxis.set_ticks_position("both")
ax7.xaxis.set_ticks_position("both")
ax7.yaxis.set_ticks_position("both")

ax0.axis([0.002, 3.5, 0.002, 3.5])
ax7.set_xlabel("$\\rho$ (K-X, mas)")
ax0.set_ylabel("$\\rho$ (All-01, mas)")
ax1.set_ylabel("$\\rho$ (All-02, mas)")
ax2.set_ylabel("$\\rho$ (Cln-01, mas)")
ax3.set_ylabel("$\\rho$ (Cln-02, mas)")
ax4.set_ylabel("$\\rho$ (Com-01, mas)")
ax5.set_ylabel("$\\rho$ (Com-02, mas)")
ax6.set_ylabel("$\\rho$ (Com-01, mas)")
ax7.set_ylabel("$\\rho$ (Com-02, mas)")

# Draw a line of y = x
x = 10**np.arange(-3, 0.6, 0.1)
ax0.plot(x, x, "r--", lw=1)
ax1.plot(x, x, "r--", lw=1)
ax2.plot(x, x, "r--", lw=1)
ax3.plot(x, x, "r--", lw=1)
ax4.plot(x, x, "r--", lw=1)
ax5.plot(x, x, "r--", lw=1)
ax6.plot(x, x, "r--", lw=1)
ax7.plot(x, x, "r--", lw=1)

plt.tight_layout()
# plt.savefig("../plots/rho-k-x-vsh.eps")

# %%
# Offset of Ka-X (original vs. adjusted by vsh01 vs. adjusted by vsh02)
fig, (ax0, ax1, ax2, ax3, ax4, ax5, ax6, ax7) = plt.subplots(
    figsize=(4, 24), nrows=8, sharex=True, sharey=True)

ax0.plot(comsou["ang_sep_ka"], comsou["ang_sep_ka_all1"], ".", ms=2)
ax1.plot(comsou["ang_sep_ka"], comsou["ang_sep_ka_all2"], ".", ms=2)
ax2.plot(comsou["ang_sep_ka"], comsou["ang_sep_ka_cln1"], ".", ms=2)
ax3.plot(comsou["ang_sep_ka"], comsou["ang_sep_ka_cln2"], ".", ms=2)
ax4.plot(comsou["ang_sep_ka"], comsou["ang_sep_ka_com1"], ".", ms=2)
ax5.plot(comsou["ang_sep_ka"], comsou["ang_sep_ka_com2"], ".", ms=2)
ax6.plot(comsou["ang_sep_ka"], comsou["ang_sep_ka_cln1"], ".", ms=2)
ax7.plot(comsou["ang_sep_ka"], comsou["ang_sep_ka_cln2"], ".", ms=2)

ax0.set_xscale("log")
ax0.set_yscale("log")

ax0.xaxis.set_ticks_position("both")
ax0.yaxis.set_ticks_position("both")
ax1.xaxis.set_ticks_position("both")
ax1.yaxis.set_ticks_position("both")
ax2.xaxis.set_ticks_position("both")
ax2.yaxis.set_ticks_position("both")
ax3.xaxis.set_ticks_position("both")
ax3.yaxis.set_ticks_position("both")
ax4.xaxis.set_ticks_position("both")
ax4.yaxis.set_ticks_position("both")
ax5.xaxis.set_ticks_position("both")
ax5.yaxis.set_ticks_position("both")
ax6.xaxis.set_ticks_position("both")
ax6.yaxis.set_ticks_position("both")
ax7.xaxis.set_ticks_position("both")
ax7.yaxis.set_ticks_position("both")

ax0.xaxis.set_ticks_position("both")
ax0.yaxis.set_ticks_position("both")
ax1.xaxis.set_ticks_position("both")
ax1.yaxis.set_ticks_position("both")


ax7.set_xlabel("$\\rho$ (Ka-X, mas)")
ax0.set_ylabel("$\\rho$ (All-01, mas)")
ax1.set_ylabel("$\\rho$ (All-02, mas)")
ax2.set_ylabel("$\\rho$ (Cln-01, mas)")
ax3.set_ylabel("$\\rho$ (Cln-02, mas)")
ax4.set_ylabel("$\\rho$ (Com-01, mas)")
ax5.set_ylabel("$\\rho$ (Com-02, mas)")
ax6.set_ylabel("$\\rho$ (Com-01, mas)")
ax7.set_ylabel("$\\rho$ (Com-02, mas)")

ax0.axis([0.002, 20, 0.002, 20])
# Draw a line of y = x
x = 10**np.arange(-3, 2, 0.1)
ax0.plot(x, x, "r--", lw=1)
ax1.plot(x, x, "r--", lw=1)
ax2.plot(x, x, "r--", lw=1)
ax3.plot(x, x, "r--", lw=1)
ax4.plot(x, x, "r--", lw=1)
ax5.plot(x, x, "r--", lw=1)
ax6.plot(x, x, "r--", lw=1)
ax7.plot(x, x, "r--", lw=1)

plt.tight_layout()
# plt.savefig("../plots/rho-ka-x-vsh.eps")

# %% [markdown]
# Modeling of VSH parameters reduce the angular separation between SX and XKa band positions.

# %%
# Offset of Gaia-X (original vs. adjusted by vsh01 vs. adjusted by vsh02)
fig, (ax0, ax1, ax2, ax3, ax4, ax5, ax6, ax7) = plt.subplots(
    figsize=(4, 24), nrows=8, sharex=True, sharey=True)

ax0.plot(comsou["ang_sep_g"], comsou["ang_sep_g_all1"], ".", ms=2)
ax1.plot(comsou["ang_sep_g"], comsou["ang_sep_g_all2"], ".", ms=2)
ax2.plot(comsou["ang_sep_g"], comsou["ang_sep_g_cln1"], ".", ms=2)
ax3.plot(comsou["ang_sep_g"], comsou["ang_sep_g_cln2"], ".", ms=2)
ax4.plot(comsou["ang_sep_g"], comsou["ang_sep_g_com1"], ".", ms=2)
ax5.plot(comsou["ang_sep_g"], comsou["ang_sep_g_com2"], ".", ms=2)
ax6.plot(comsou["ang_sep_g"], comsou["ang_sep_g_cln1"], ".", ms=2)
ax7.plot(comsou["ang_sep_g"], comsou["ang_sep_g_cln2"], ".", ms=2)

ax0.set_xscale("log")
ax0.set_yscale("log")

ax0.xaxis.set_ticks_position("both")
ax0.yaxis.set_ticks_position("both")
ax1.xaxis.set_ticks_position("both")
ax1.yaxis.set_ticks_position("both")
ax2.xaxis.set_ticks_position("both")
ax2.yaxis.set_ticks_position("both")
ax3.xaxis.set_ticks_position("both")
ax3.yaxis.set_ticks_position("both")
ax4.xaxis.set_ticks_position("both")
ax4.yaxis.set_ticks_position("both")
ax5.xaxis.set_ticks_position("both")
ax5.yaxis.set_ticks_position("both")
ax6.xaxis.set_ticks_position("both")
ax6.yaxis.set_ticks_position("both")
ax7.xaxis.set_ticks_position("both")
ax7.yaxis.set_ticks_position("both")

ax0.xaxis.set_ticks_position("both")
ax0.yaxis.set_ticks_position("both")
ax1.xaxis.set_ticks_position("both")
ax1.yaxis.set_ticks_position("both")


ax7.set_xlabel("$\\rho$ (Gaia-X, mas)")
ax0.set_ylabel("$\\rho$ (All-01, mas)")
ax1.set_ylabel("$\\rho$ (All-02, mas)")
ax2.set_ylabel("$\\rho$ (Cln-01, mas)")
ax3.set_ylabel("$\\rho$ (Cln-02, mas)")
ax4.set_ylabel("$\\rho$ (Com-01, mas)")
ax5.set_ylabel("$\\rho$ (Com-02, mas)")
ax6.set_ylabel("$\\rho$ (Com-01, mas)")
ax7.set_ylabel("$\\rho$ (Com-02, mas)")

ax0.axis([0.01, 15, 0.01, 15])
# Draw a line of y = x
x = 10**np.arange(-2.1, 1.2, 0.1)
ax0.plot(x, x, "r--", lw=1)
ax1.plot(x, x, "r--", lw=1)
ax2.plot(x, x, "r--", lw=1)
ax3.plot(x, x, "r--", lw=1)
ax4.plot(x, x, "r--", lw=1)
ax5.plot(x, x, "r--", lw=1)
ax6.plot(x, x, "r--", lw=1)
ax7.plot(x, x, "r--", lw=1)

plt.tight_layout()
# plt.savefig("../plots/rho-gaia-x-vsh.eps")

# %% [markdown]
# # 3. On normalized separation

# %%
# Offset of K-X (original vs. adjusted by vsh01 vs. adjusted by vsh02)
fig, (ax0, ax1, ax2, ax3, ax4, ax5, ax6, ax7) = plt.subplots(
    figsize=(4, 24), nrows=8, sharex=True, sharey=True)

ax0.plot(comsou["nor_sep_k"], comsou["nor_sep_k_all1"], ".", ms=2)
ax1.plot(comsou["nor_sep_k"], comsou["nor_sep_k_all2"], ".", ms=2)
ax2.plot(comsou["nor_sep_k"], comsou["nor_sep_k_cln1"], ".", ms=2)
ax3.plot(comsou["nor_sep_k"], comsou["nor_sep_k_cln2"], ".", ms=2)
ax4.plot(comsou["nor_sep_k"], comsou["nor_sep_k_com1"], ".", ms=2)
ax5.plot(comsou["nor_sep_k"], comsou["nor_sep_k_com2"], ".", ms=2)
ax6.plot(comsou["nor_sep_k"], comsou["nor_sep_k_cln1"], ".", ms=2)
ax7.plot(comsou["nor_sep_k"], comsou["nor_sep_k_cln2"], ".", ms=2)

ax0.set_xscale("log")
ax0.set_yscale("log")

ax0.xaxis.set_ticks_position("both")
ax0.yaxis.set_ticks_position("both")
ax1.xaxis.set_ticks_position("both")
ax1.yaxis.set_ticks_position("both")
ax2.xaxis.set_ticks_position("both")
ax2.yaxis.set_ticks_position("both")
ax3.xaxis.set_ticks_position("both")
ax3.yaxis.set_ticks_position("both")
ax4.xaxis.set_ticks_position("both")
ax4.yaxis.set_ticks_position("both")
ax5.xaxis.set_ticks_position("both")
ax5.yaxis.set_ticks_position("both")
ax6.xaxis.set_ticks_position("both")
ax6.yaxis.set_ticks_position("both")
ax7.xaxis.set_ticks_position("both")
ax7.yaxis.set_ticks_position("both")

ax7.set_xlabel("$X$ (K-X)")
ax0.set_ylabel("$X$ (All-01)")
ax1.set_ylabel("$X$ (All-02)")
ax2.set_ylabel("$X$ (Cln-01)")
ax3.set_ylabel("$X$ (Cln-02)")
ax4.set_ylabel("$X$ (Com-01)")
ax5.set_ylabel("$X$ (Com-02)")
ax6.set_ylabel("$X$ (Com-01)")
ax7.set_ylabel("$X$ (Com-02)")

ax0.axis([0.05, 22, 0.05, 22])
# Draw a line of y = x
x = 10**np.arange(-1.5, 1.4, 0.1)
ax0.plot(x, x, "r--", lw=1)
ax1.plot(x, x, "r--", lw=1)
ax2.plot(x, x, "r--", lw=1)
ax3.plot(x, x, "r--", lw=1)
ax4.plot(x, x, "r--", lw=1)
ax5.plot(x, x, "r--", lw=1)
ax6.plot(x, x, "r--", lw=1)
ax7.plot(x, x, "r--", lw=1)

plt.tight_layout()
# plt.savefig("../plots/X-k-x-vsh.eps")

# %%
# Offset of Ka-X (original vs. adjusted by vsh01 vs. adjusted by vsh02)
fig, (ax0, ax1, ax2, ax3, ax4, ax5, ax6, ax7) = plt.subplots(
    figsize=(4, 24), nrows=8, sharex=True, sharey=True)

ax0.plot(comsou["nor_sep_ka"], comsou["nor_sep_ka_all1"], ".", ms=2)
ax1.plot(comsou["nor_sep_ka"], comsou["nor_sep_ka_all2"], ".", ms=2)
ax2.plot(comsou["nor_sep_ka"], comsou["nor_sep_ka_cln1"], ".", ms=2)
ax3.plot(comsou["nor_sep_ka"], comsou["nor_sep_ka_cln2"], ".", ms=2)
ax4.plot(comsou["nor_sep_ka"], comsou["nor_sep_ka_com1"], ".", ms=2)
ax5.plot(comsou["nor_sep_ka"], comsou["nor_sep_ka_com2"], ".", ms=2)
ax6.plot(comsou["nor_sep_ka"], comsou["nor_sep_ka_cln1"], ".", ms=2)
ax7.plot(comsou["nor_sep_ka"], comsou["nor_sep_ka_cln2"], ".", ms=2)

ax0.set_xscale("log")
ax0.set_yscale("log")

ax0.xaxis.set_ticks_position("both")
ax0.yaxis.set_ticks_position("both")
ax1.xaxis.set_ticks_position("both")
ax1.yaxis.set_ticks_position("both")
ax2.xaxis.set_ticks_position("both")
ax2.yaxis.set_ticks_position("both")
ax3.xaxis.set_ticks_position("both")
ax3.yaxis.set_ticks_position("both")
ax4.xaxis.set_ticks_position("both")
ax4.yaxis.set_ticks_position("both")
ax5.xaxis.set_ticks_position("both")
ax5.yaxis.set_ticks_position("both")
ax6.xaxis.set_ticks_position("both")
ax6.yaxis.set_ticks_position("both")
ax7.xaxis.set_ticks_position("both")
ax7.yaxis.set_ticks_position("both")

ax0.xaxis.set_ticks_position("both")
ax0.yaxis.set_ticks_position("both")
ax1.xaxis.set_ticks_position("both")
ax1.yaxis.set_ticks_position("both")


ax7.set_xlabel("$X$ (Ka-X)")
ax0.set_ylabel("$X$ (All-01)")
ax1.set_ylabel("$X$ (All-02)")
ax2.set_ylabel("$X$ (Cln-01)")
ax3.set_ylabel("$X$ (Cln-02)")
ax4.set_ylabel("$X$ (Com-01)")
ax5.set_ylabel("$X$ (Com-02)")
ax6.set_ylabel("$X$ (Com-01)")
ax7.set_ylabel("$X$ (Com-02)")

ax0.axis([0.03, 22, 0.03, 22])
# Draw a line of y = x
x = 10**np.arange(-1.6, 1.3, 0.1)
ax0.plot(x, x, "r--", lw=1)
ax1.plot(x, x, "r--", lw=1)
ax2.plot(x, x, "r--", lw=1)
ax3.plot(x, x, "r--", lw=1)
ax4.plot(x, x, "r--", lw=1)
ax5.plot(x, x, "r--", lw=1)
ax6.plot(x, x, "r--", lw=1)
ax7.plot(x, x, "r--", lw=1)

plt.tight_layout()
# plt.savefig("../plots/X-ka-x-vsh.eps")

# %%
# Offset of Gaia-X (original vs. adjusted by vsh01 vs. adjusted by vsh02)
fig, (ax0, ax1, ax2, ax3, ax4, ax5, ax6, ax7) = plt.subplots(
    figsize=(4, 24), nrows=8, sharex=True, sharey=True)

ax0.plot(comsou["nor_sep_g"], comsou["nor_sep_g_all1"], ".", ms=2)
ax1.plot(comsou["nor_sep_g"], comsou["nor_sep_g_all2"], ".", ms=2)
ax2.plot(comsou["nor_sep_g"], comsou["nor_sep_g_cln1"], ".", ms=2)
ax3.plot(comsou["nor_sep_g"], comsou["nor_sep_g_cln2"], ".", ms=2)
ax4.plot(comsou["nor_sep_g"], comsou["nor_sep_g_com1"], ".", ms=2)
ax5.plot(comsou["nor_sep_g"], comsou["nor_sep_g_com2"], ".", ms=2)
ax6.plot(comsou["nor_sep_g"], comsou["nor_sep_g_cln1"], ".", ms=2)
ax7.plot(comsou["nor_sep_g"], comsou["nor_sep_g_cln2"], ".", ms=2)

ax0.set_xscale("log")
ax0.set_yscale("log")

ax0.xaxis.set_ticks_position("both")
ax0.yaxis.set_ticks_position("both")
ax1.xaxis.set_ticks_position("both")
ax1.yaxis.set_ticks_position("both")
ax2.xaxis.set_ticks_position("both")
ax2.yaxis.set_ticks_position("both")
ax3.xaxis.set_ticks_position("both")
ax3.yaxis.set_ticks_position("both")
ax4.xaxis.set_ticks_position("both")
ax4.yaxis.set_ticks_position("both")
ax5.xaxis.set_ticks_position("both")
ax5.yaxis.set_ticks_position("both")
ax6.xaxis.set_ticks_position("both")
ax6.yaxis.set_ticks_position("both")
ax7.xaxis.set_ticks_position("both")
ax7.yaxis.set_ticks_position("both")

ax0.xaxis.set_ticks_position("both")
ax0.yaxis.set_ticks_position("both")
ax1.xaxis.set_ticks_position("both")
ax1.yaxis.set_ticks_position("both")


ax7.set_xlabel("$X$ (Gaia-X)")
ax0.set_ylabel("$X$ (All-01)")
ax1.set_ylabel("$X$ (All-02)")
ax2.set_ylabel("$X$ (Cln-01)")
ax3.set_ylabel("$X$ (Cln-02)")
ax4.set_ylabel("$X$ (Com-01)")
ax5.set_ylabel("$X$ (Com-02)")
ax6.set_ylabel("$X$ (Com-01)")
ax7.set_ylabel("$X$ (Com-02)")

ax0.axis([0.03, 110, 0.03, 110])
# Draw a line of y = x
x = 10**np.arange(-1.8, 2.1, 0.1)
ax0.plot(x, x, "r--", lw=1)
ax1.plot(x, x, "r--", lw=1)
ax2.plot(x, x, "r--", lw=1)
ax3.plot(x, x, "r--", lw=1)
ax4.plot(x, x, "r--", lw=1)
ax5.plot(x, x, "r--", lw=1)
ax6.plot(x, x, "r--", lw=1)
ax7.plot(x, x, "r--", lw=1)

plt.tight_layout()
# plt.savefig("../plots/X-gaia-x-vsh.eps")

# %% [markdown]
# # 4. On the positional offset direction

# %%
# The positional angle difference of K-X (original vs. adjusted by vsh01 vs. adjusted by vsh02)
fig, (ax0, ax1, ax2, ax3, ax4, ax5, ax6, ax7) = plt.subplots(
    figsize=(4, 24), nrows=8, sharex=True, sharey=True)

ax0.plot(comsou["pa_k"], comsou["pa_k_all1"], ".", ms=2)
ax1.plot(comsou["pa_k"], comsou["pa_k_all2"], ".", ms=2)
ax2.plot(comsou["pa_k"], comsou["pa_k_cln1"], ".", ms=2)
ax3.plot(comsou["pa_k"], comsou["pa_k_cln2"], ".", ms=2)
ax4.plot(comsou["pa_k"], comsou["pa_k_com1"], ".", ms=2)
ax5.plot(comsou["pa_k"], comsou["pa_k_com2"], ".", ms=2)
ax6.plot(comsou["pa_k"], comsou["pa_k_cln1"], ".", ms=2)
ax7.plot(comsou["pa_k"], comsou["pa_k_cln2"], ".", ms=2)

ax0.xaxis.set_ticks_position("both")
ax0.yaxis.set_ticks_position("both")
ax1.xaxis.set_ticks_position("both")
ax1.yaxis.set_ticks_position("both")
ax2.xaxis.set_ticks_position("both")
ax2.yaxis.set_ticks_position("both")
ax3.xaxis.set_ticks_position("both")
ax3.yaxis.set_ticks_position("both")
ax4.xaxis.set_ticks_position("both")
ax4.yaxis.set_ticks_position("both")
ax5.xaxis.set_ticks_position("both")
ax5.yaxis.set_ticks_position("both")
ax6.xaxis.set_ticks_position("both")
ax6.yaxis.set_ticks_position("both")
ax7.xaxis.set_ticks_position("both")
ax7.yaxis.set_ticks_position("both")

ax7.set_xlabel("PA (K-X, $^\circ$)")
ax0.set_ylabel("PA (All-01, $^\circ$)")
ax1.set_ylabel("PA (All-02, $^\circ$)")
ax2.set_ylabel("PA (Cln-01, $^\circ$)")
ax3.set_ylabel("PA (Cln-02, $^\circ$)")
ax4.set_ylabel("PA (Com-01, $^\circ$)")
ax5.set_ylabel("PA (Com-02, $^\circ$)")
ax6.set_ylabel("PA (Com-01, $^\circ$)")
ax7.set_ylabel("PA (Com-02, $^\circ$)")

ax0.axis([0, 360, 0, 360])
ax0.xaxis.set_minor_locator(MultipleLocator(30))
ax0.yaxis.set_minor_locator(MultipleLocator(30))
ax0.set_xticks(np.arange(0, 361, 90))
ax0.set_yticks(np.arange(0, 361, 90))
# Draw a line of y = x
x = np.arange(360)
ax0.plot(x, x, "r--", lw=1)
ax1.plot(x, x, "r--", lw=1)
ax2.plot(x, x, "r--", lw=1)
ax3.plot(x, x, "r--", lw=1)
ax4.plot(x, x, "r--", lw=1)
ax5.plot(x, x, "r--", lw=1)
ax6.plot(x, x, "r--", lw=1)
ax7.plot(x, x, "r--", lw=1)

plt.tight_layout()
# plt.savefig("../plots/pa-diff-from-sys-k-x.eps")

# %%
# The positional angle difference of Ka-X (original vs. adjusted by vsh01 vs. adjusted by vsh02)
fig, (ax0, ax1, ax2, ax3, ax4, ax5, ax6, ax7) = plt.subplots(
    figsize=(4, 24), nrows=8, sharex=True, sharey=True)

ax0.plot(comsou["pa_ka"], comsou["pa_ka_all1"], ".", ms=2)
ax1.plot(comsou["pa_ka"], comsou["pa_ka_all2"], ".", ms=2)
ax2.plot(comsou["pa_ka"], comsou["pa_ka_cln1"], ".", ms=2)
ax3.plot(comsou["pa_ka"], comsou["pa_ka_cln2"], ".", ms=2)
ax4.plot(comsou["pa_ka"], comsou["pa_ka_com1"], ".", ms=2)
ax5.plot(comsou["pa_ka"], comsou["pa_ka_com2"], ".", ms=2)
ax6.plot(comsou["pa_ka"], comsou["pa_ka_cln1"], ".", ms=2)
ax7.plot(comsou["pa_ka"], comsou["pa_ka_cln2"], ".", ms=2)

ax0.xaxis.set_ticks_position("both")
ax0.yaxis.set_ticks_position("both")
ax1.xaxis.set_ticks_position("both")
ax1.yaxis.set_ticks_position("both")
ax2.xaxis.set_ticks_position("both")
ax2.yaxis.set_ticks_position("both")
ax3.xaxis.set_ticks_position("both")
ax3.yaxis.set_ticks_position("both")
ax4.xaxis.set_ticks_position("both")
ax4.yaxis.set_ticks_position("both")
ax5.xaxis.set_ticks_position("both")
ax5.yaxis.set_ticks_position("both")
ax6.xaxis.set_ticks_position("both")
ax6.yaxis.set_ticks_position("both")
ax7.xaxis.set_ticks_position("both")
ax7.yaxis.set_ticks_position("both")

ax7.set_xlabel("PA (Ka-X, $^\circ$)")
ax0.set_ylabel("PA (All-01, $^\circ$)")
ax1.set_ylabel("PA (All-02, $^\circ$)")
ax2.set_ylabel("PA (Cln-01, $^\circ$)")
ax3.set_ylabel("PA (Cln-02, $^\circ$)")
ax4.set_ylabel("PA (Com-01, $^\circ$)")
ax5.set_ylabel("PA (Com-02, $^\circ$)")
ax6.set_ylabel("PA (Com-01, $^\circ$)")
ax7.set_ylabel("PA (Com-02, $^\circ$)")

ax0.axis([0, 360, 0, 360])
ax0.xaxis.set_minor_locator(MultipleLocator(30))
ax0.yaxis.set_minor_locator(MultipleLocator(30))
ax0.set_xticks(np.arange(0, 361, 90))
ax0.set_yticks(np.arange(0, 361, 90))
# Draw a line of y = x
x = np.arange(360)
ax0.plot(x, x, "r--", lw=1)
ax1.plot(x, x, "r--", lw=1)
ax2.plot(x, x, "r--", lw=1)
ax3.plot(x, x, "r--", lw=1)
ax4.plot(x, x, "r--", lw=1)
ax5.plot(x, x, "r--", lw=1)
ax6.plot(x, x, "r--", lw=1)
ax7.plot(x, x, "r--", lw=1)

plt.tight_layout()
# plt.savefig("../plots/pa-diff-from-sys-ka-x.eps")

# %%
# The positional angle difference of Gaia-X (original vs. adjusted by vsh01 vs. adjusted by vsh02)
fig, (ax0, ax1, ax2, ax3, ax4, ax5, ax6, ax7) = plt.subplots(
    figsize=(4, 24), nrows=8, sharex=True, sharey=True)

ax0.plot(comsou["pa_g"], comsou["pa_g_all1"], ".", ms=2)
ax1.plot(comsou["pa_g"], comsou["pa_g_all2"], ".", ms=2)
ax2.plot(comsou["pa_g"], comsou["pa_g_cln1"], ".", ms=2)
ax3.plot(comsou["pa_g"], comsou["pa_g_cln2"], ".", ms=2)
ax4.plot(comsou["pa_g"], comsou["pa_g_com1"], ".", ms=2)
ax5.plot(comsou["pa_g"], comsou["pa_g_com2"], ".", ms=2)
ax6.plot(comsou["pa_g"], comsou["pa_g_cln1"], ".", ms=2)
ax7.plot(comsou["pa_g"], comsou["pa_g_cln2"], ".", ms=2)

ax0.xaxis.set_ticks_position("both")
ax0.yaxis.set_ticks_position("both")
ax1.xaxis.set_ticks_position("both")
ax1.yaxis.set_ticks_position("both")
ax2.xaxis.set_ticks_position("both")
ax2.yaxis.set_ticks_position("both")
ax3.xaxis.set_ticks_position("both")
ax3.yaxis.set_ticks_position("both")
ax4.xaxis.set_ticks_position("both")
ax4.yaxis.set_ticks_position("both")
ax5.xaxis.set_ticks_position("both")
ax5.yaxis.set_ticks_position("both")
ax6.xaxis.set_ticks_position("both")
ax6.yaxis.set_ticks_position("both")
ax7.xaxis.set_ticks_position("both")
ax7.yaxis.set_ticks_position("both")

ax7.set_xlabel("PA (Gaia-X, $^\circ$)")
ax0.set_ylabel("PA (All-01, $^\circ$)")
ax1.set_ylabel("PA (All-02, $^\circ$)")
ax2.set_ylabel("PA (Cln-01, $^\circ$)")
ax3.set_ylabel("PA (Cln-02, $^\circ$)")
ax4.set_ylabel("PA (Com-01, $^\circ$)")
ax5.set_ylabel("PA (Com-02, $^\circ$)")
ax6.set_ylabel("PA (Com-01, $^\circ$)")
ax7.set_ylabel("PA (Com-02, $^\circ$)")

ax0.axis([0, 360, 0, 360])
ax0.xaxis.set_minor_locator(MultipleLocator(30))
ax0.yaxis.set_minor_locator(MultipleLocator(30))
ax0.set_xticks(np.arange(0, 361, 90))
ax0.set_yticks(np.arange(0, 361, 90))
# Draw a line of y = x
x = np.arange(360)
ax0.plot(x, x, "r--", lw=1)
ax1.plot(x, x, "r--", lw=1)
ax2.plot(x, x, "r--", lw=1)
ax3.plot(x, x, "r--", lw=1)
ax4.plot(x, x, "r--", lw=1)
ax5.plot(x, x, "r--", lw=1)
ax6.plot(x, x, "r--", lw=1)
ax7.plot(x, x, "r--", lw=1)

plt.tight_layout()
# plt.savefig("../plots/pa-diff-from-sys-gaia-x.eps")
