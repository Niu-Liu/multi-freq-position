# %%
from astropy.table import Table, join

from my_progs.catalog.read_icrf import read_icrf3
from my_progs.catalog.read_gaia import read_dr2_iers

# %%
icrf3sx = read_icrf3(wv="sx")
icrf3k = read_icrf3(wv="k")
icrf3ka = read_icrf3(wv="xka")
gdr2 = read_dr2_iers()

icrf3sx.remove_columns(["icrf_name", "type"])
icrf3k.remove_columns(["icrf_name", "type"])
icrf3ka.remove_columns(["icrf_name", "type"])

tmp = join(icrf3sx, icrf3k, keys="iers_name", table_names=["x", "k"])
tmp = join(tmp, icrf3ka, keys="iers_name", table_names=["", "ka"])
comsou = join(tmp, gdr2, keys="iers_name", table_names=["", "g"])

# %%
def print_median_err(cat):
    """
    """
# Out:
# <Table masked=True length=488>
# iers_name        ra_x               dec_x        ... phot_rp_mean_mag   bp_rp
#                  deg                 deg         ...       mag           mag
#    str8        float64             float64       ...     float32       float32
# --------- ------------------ ------------------- ... ---------------- ----------
#  0002+541 1.2681806087916665   54.47359013780556 ...         17.97392 0.74580574
#  0002-478 1.1485645219166665  -47.60544555705556 ...        19.225542 0.77326584
#  0003+380 1.4882307787916664   38.33754137886111 ...         17.15951  1.7173595
#  0003-066 1.5578870200833332  -6.393148710666667 ...         16.27626  1.3696098
#  0006+061 2.2663826755416663   6.472566729833334 ...        17.271818   1.116909
#  0007+106 2.6291912672083333  10.974862305027777 ...        15.158809  1.0046282
#  0008-264  2.755194738583333 -26.209271426111112 ...        18.506237  0.4915123
#  0009+081 2.8969567103749996   8.398773932527778 ...        18.558659 0.77002716
#  0010-401      3.24962424175  -39.90723763269445 ...        18.163582  1.1089611
#       ...                ...                 ... ...              ...        ...
#  2344-514  356.8327670139166  -51.17668481986111 ...        18.601587  0.7136307
#  2345+061 357.13237776349996  6.4166061138611115 ...        17.978302 0.85640335
#  2346+385  357.3367772635833   38.82154404863889 ...        17.805563  0.6682682
#  2351+456  358.5903342708749   45.88451015333333 ...         19.82888  1.4449596
#  2351-154  358.6258132139166 -15.219781388388888 ...        18.203224  0.4795704
#  2353+816  359.0949746452499   81.88118197180555 ...         19.46929  1.6610718
#  2354-021 359.35474138687493 -1.8709747324722223 ...        17.608013  1.0709877
#  2355-106  359.5453433192499 -10.335725393722223 ...        17.523247   0.802042
#  2355-534 359.47194187566663  -53.18713597280555 ...        18.330183  0.6429157
#  2357-318   359.897881414125 -31.562173523166667 ...        18.695164  0.7715092
